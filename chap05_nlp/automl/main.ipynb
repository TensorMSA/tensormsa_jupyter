# %%
"""Entry point to evolving the neural network. Start here."""
import logging
from optimizer import Optimizer

def train_networks(networks, dataset):
    """Train each network.
    Args:
        networks (list): Current population of networks
        dataset (str): Dataset to use for training/evaluating
    """
    for network in networks:
        network.train(dataset, skip_real_train=skip_train)

def get_average_accuracy(networks):
    """Get the average accuracy for a group of networks.
    Args:
        networks (list): List of networks
    Returns:
        float: The average accuracy of a population of networks.
    """
    total_accuracy = 0
    for network in networks:
        total_accuracy += network.accuracy

    return total_accuracy / len(networks)

def generate(generations, population, nn_param_choices, dataset):
    """Generate a network with the genetic algorithm.
    Args:
        generations (int): Number of times to evole the population
        population (int): Number of networks in each generation
        nn_param_choices (dict): Parameter choices for networks
        dataset (str): Dataset to use for training/evaluating
    """
    optimizer = Optimizer(nn_param_choices)
    networks = optimizer.create_population(population)

    # Evolve the generation.
    for i in range(generations):
        print('='*80)
        print("***Doing generation %d of %d***" %
                     (i + 1, generations))

        # Train and get accuracy for networks.
        train_networks(networks, dataset)

        # Get the average accuracy for this generation.
        average_accuracy = get_average_accuracy(networks)

        # Print out the average accuracy each generation.
        print("Generation average: %.2f%%" % (average_accuracy * 100))

        # Evolve, except on the last iteration.
        if i != generations - 1:
            # Do the evolution.
            networks = optimizer.evolve(networks)
            
        print('='*80)
        
    # Sort our final population.
    networks = sorted(networks, key=lambda x: x.accuracy, reverse=True)

    # Print out the top 5 networks.
    print_networks(networks[:5])

def print_networks(networks):
    """Print a list of networks.
    Args:
        networks (list): The population of networks
    """
    print('-'*80)
    for network in networks:
        network.print_network()

def main():
    """Evolve a network."""
    generations = 10  # Number of times to evole the population.
    population = 20  # Number of networks in each generation.
    dataset = 'cifar10'

    nn_param_choices = {
        'nb_neurons': [64, 128, 256, 512, 768, 1024],
        'nb_layers': [1, 2, 3, 4],
        'activation': ['relu', 'elu', 'tanh', 'sigmoid'],
        'optimizer': ['rmsprop', 'adam', 'sgd', 'adagrad',
                      'adadelta', 'adamax', 'nadam'],
    }
    
    print("Hyper Parameter Ranges : {0}".format(nn_param_choices))

    print("***Evolving %d generations with population %d***" %
                 (generations, population))

    generate(generations, population, nn_param_choices, dataset)
# Out:
# Using TensorFlow backend.

# %%
skip_train = True
main()
# Out:
# Hyper Parameter Ranges : {'activation': ['relu', 'elu', 'tanh', 'sigmoid'], 'nb_neurons': [64, 128, 256, 512, 768, 1024], 'nb_layers': [1, 2, 3, 4], 'optimizer': ['rmsprop', 'adam', 'sgd', 'adagrad', 'adadelta', 'adamax', 'nadam']}
# ***Evolving 10 generations with population 20***
# ================================================================================
# ***Doing generation 1 of 10***
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 2, 'optimizer': 'sgd'}
# Test result of each network : 0.8
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 3, 'optimizer': 'adam'}
# Test result of each network : 0.57
# Test condition of each network : {'activation': 'tanh', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.23
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.66
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.9
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 1024, 'nb_layers': 2, 'optimizer': 'nadam'}
# Test result of each network : 0.57
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.3
# Test condition of each network : {'activation': 'tanh', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'nadam'}
# Test result of each network : 0.76
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 768, 'nb_layers': 4, 'optimizer': 'adam'}
# Test result of each network : 0.59
# Test condition of each network : {'activation': 'tanh', 'nb_neurons': 1024, 'nb_layers': 2, 'optimizer': 'adadelta'}
# Test result of each network : 0.52
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.99
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 1024, 'nb_layers': 3, 'optimizer': 'adadelta'}
# Test result of each network : 0.08
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 768, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.16
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.34
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 768, 'nb_layers': 2, 'optimizer': 'adagrad'}
# Test result of each network : 0.03
# Test condition of each network : {'activation': 'sigmoid', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'nadam'}
# Test result of each network : 0.8
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adam'}
# Test result of each network : 0.94
# Test condition of each network : {'activation': 'sigmoid', 'nb_neurons': 128, 'nb_layers': 1, 'optimizer': 'rmsprop'}
# Test result of each network : 0.2
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 768, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.68
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 768, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.32
# Generation average: 52.20%
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 2 of 10***
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.78
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.45
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 768, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.78
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.0
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.51
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'nadam'}
# Test result of each network : 0.72
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.11
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.36
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adam'}
# Test result of each network : 0.0
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'sgd'}
# Test result of each network : 0.25
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.98
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.98
# Generation average: 62.25%
# mutation
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 3 of 10***
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.3
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.41
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.78
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.22
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.47
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'nadam'}
# Test result of each network : 0.28
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.15
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.01
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adam'}
# Test result of each network : 0.2
# Generation average: 56.05%
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 4 of 10***
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.91
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.25
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.7
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.1
# Test condition of each network : {'activation': 'sigmoid', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'nadam'}
# Test result of each network : 0.11
# Test condition of each network : {'activation': 'sigmoid', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.97
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adamax'}
# Test result of each network : 0.82
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.97
# Test condition of each network : {'activation': 'sigmoid', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'nadam'}
# Test result of each network : 0.59
# Test condition of each network : {'activation': 'sigmoid', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'nadam'}
# Test result of each network : 0.63
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 2, 'optimizer': 'adam'}
# Test result of each network : 0.74
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'sgd'}
# Test result of each network : 0.97
# Generation average: 74.65%
# mutation
# mutation
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 5 of 10***
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'sgd'}
# Test result of each network : 0.87
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.02
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.7
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.91
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.88
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.32
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.08
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.03
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.83
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.01
# Generation average: 70.30%
# cross over
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 6 of 10***
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 512, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.39
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.49
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.95
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.82
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.45
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.68
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.43
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.61
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.76
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.14
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.96
# Generation average: 76.50%
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 7 of 10***
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 2, 'optimizer': 'adamax'}
# Test result of each network : 0.39
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adamax'}
# Test result of each network : 0.35
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.08
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adagrad'}
# Test result of each network : 0.27
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adamax'}
# Test result of each network : 0.59
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.37
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.58
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.22
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.12
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.47
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.77
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.26
# Generation average: 61.20%
# mutation
# mutation
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 8 of 10***
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.58
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adagrad'}
# Test result of each network : 0.31
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adagrad'}
# Test result of each network : 0.02
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adagrad'}
# Test result of each network : 0.06
# Test condition of each network : {'activation': 'tanh', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.8
# Test condition of each network : {'activation': 'tanh', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.16
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.9
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adamax'}
# Test result of each network : 0.25
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.1
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.64
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.83
# Generation average: 63.40%
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 9 of 10***
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adagrad'}
# Test result of each network : 0.57
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.93
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.33
# Test condition of each network : {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.78
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.38
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.2
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.78
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'adagrad'}
# Test result of each network : 0.85
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.03
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.84
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 2, 'optimizer': 'sgd'}
# Test result of each network : 0.64
# Generation average: 70.80%
# mutation
# mutation
# mutation
# cross over
# cross over
# cross over
# cross over
# cross over
# ================================================================================
# ================================================================================
# ***Doing generation 10 of 10***
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.63
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 512, 'nb_layers': 2, 'optimizer': 'adagrad'}
# Test result of each network : 0.17
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.84
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Test result of each network : 0.37
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.14
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Test result of each network : 0.28
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'sgd'}
# Test result of each network : 0.6
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.81
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Test result of each network : 0.83
# Test condition of each network : {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Test result of each network : 0.84
# Generation average: 67.70%
# ================================================================================
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Top 5 result
# {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 1, 'optimizer': 'sgd'}
# Network accuracy: 99.00%
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Top 5 result
# {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Network accuracy: 98.00%
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Top 5 result
# {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'adagrad'}
# Network accuracy: 98.00%
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Top 5 result
# {'activation': 'elu', 'nb_neurons': 256, 'nb_layers': 3, 'optimizer': 'sgd'}
# Network accuracy: 97.00%
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Top 5 result
# {'activation': 'relu', 'nb_neurons': 256, 'nb_layers': 4, 'optimizer': 'adagrad'}
# Network accuracy: 97.00%
# --------------------------------------------------------------------------------
